# %%
import pandas as pd
import numpy as np

# create a datetime index for the data
date_rng = pd.date_range(start='1/01/2022', end='1/08/2022', freq='H')

# create a dataframe with datetime index and random values
data = pd.DataFrame(date_rng, columns=['date'])
data['data'] = np.random.randint(0,100,size=(len(date_rng)))
data.set_index('date', inplace=True)

print(data.head())
# Out:
#                      data
# date
# 2022-01-01 00:00:00    39
# 2022-01-01 01:00:00    11
# 2022-01-01 02:00:00     0
# 2022-01-01 03:00:00    81
# 2022-01-01 04:00:00    13

# %%
diff_data = data.diff().dropna()
plt.plot(diff_data)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(diff_data)
plot_pacf(diff_data)
# Out:
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
model = ARIMA(diff_data, order=(1, 0, 1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:                   data   No. Observations:                  168
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -797.083
# Date:                Sun, 09 Apr 2023   AIC                           1602.167
# Time:                        16:39:03   BIC                           1614.663
# ...

# %%
train_data = diff_data[:-12]
test_data = diff_data[-12:]
model = ARIMA(train_data, order=(1, 0, 1))
model_fit = model.fit()
preds = model_fit.forecast(steps=12)
# Out:
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# C:\Users\paliw\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)

# %%
rmse = np.sqrt(mean_squared_error(test_data, preds))
print(f'RMSE: {rmse:.2f}')
# Out:
# RMSE: 36.96

# %%
future_preds = model_fit.forecast(steps=24)
pred_values = model_fit.forecast(steps=len(test_data))[0]
 # extract predicted values from future_preds

# concatenate train_data, test_data, and pred_values
ts_values = np.concatenate([train_data, test_data, pred_values.reshape(-1,1)])

# create a new time index for the predicted values
future_dates = pd.date_range(start='1/9/2022', end='1/10/2022', freq='H')

# plot the original and predicted time series
plt.plot(data.index, data.values)
plt.plot(future_dates, pred_values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19336/150676054.py in <module>
#      11 # plot the original and predicted time series
#      12 plt.plot(data.index, data.values)
# ---> 13 plt.plot(future_dates, pred_values)
#      14 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
