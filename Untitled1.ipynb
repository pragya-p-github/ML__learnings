# %%
import altair as alt
import datapane as dp
from vega_datasets import data

# %%
df = data.iris()
columns = list(df.columns)
data.iris().head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
fig = (
    alt.Chart(df)
    .mark_point()
    .encode(x=alt.X("sepalLength", scale=alt.Scale(zero=False)), 
            y=alt.X("sepalWidth", scale=alt.Scale(zero=False)),
            color="species")
)

view = dp.Select(dp.Plot(fig, label="Plot"), dp.DataTable(df, label="Data"))
view
# Out:
# <style>
#   #dp-e4cd6bbaa2e441448d4503b98bd0b006 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="dp-e4cd6bbaa2e441448d4503b98bd0b006" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.2/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.2/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = true;
#     window.dpReportId = &quot;e4cd6bbaa2e441448d4503b98bd0b006&quot;;
#     window.dpAuthorId = &quot;caa5f20a74684e2fa3c1dc94c4cdf965&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cSelect type=\&quot;tabs\&quot;\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; label=\&quot;Plot\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://9188c68059\&quot;/\u003e\u003cDataTable type=\&quot;application/vnd.apache.arrow+binary\&quot; label=\&quot;Data\&quot; rows=\&quot;150\&quot; columns=\&quot;5\&quot; schema=\&quot;[]\&quot; src=\&quot;ref://4150a8a36f\&quot;/\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; label=\&quot;Plot\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://9188c68059\&quot;/\u003e\u003c/Select\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;9188c68059&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;9188c68059&quot;, &quot;size&quot;: 21620, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}, &quot;4150a8a36f&quot;: {&quot;src&quot;: &quot;data:application/vnd.apache.arrow+binary;base64,...&quot;, &quot;hash&quot;: &quot;4150a8a36f&quot;, &quot;size&quot;: 10736, &quot;mime&quot;: &quot;application/vnd.apache.arrow+binary&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.2/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://datapane-cdn.com/v0.16.2/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://datapane-cdn.com/v0.16.2/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#dp-e4cd6bbaa2e441448d4503b98bd0b006");
# </script>

# %%
dp.save_report(view, "quickstart_report.html", open=True)
# Out:
# App saved to ./quickstart_report.html

# %%
def plot_df(x_axis: str, y_axis: str, color: str) -> dp.Plot:
    # global dataset
    fig = (
        alt.Chart(df)
        .mark_point()
        .encode(
            x=alt.X(x_axis, scale=alt.Scale(zero=False)),
            y=alt.X(y_axis, scale=alt.Scale(zero=False)),
            color=color,
            tooltip=columns,
        )
    )

    return dp.Plot(fig, name="plot")

plot_df(x_axis="sepalLength", y_axis="sepalWidth", color="species")
# Out:
# <style>
#   #dp-1d467386194a48349a9ea6ec89cc708d {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="dp-1d467386194a48349a9ea6ec89cc708d" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link rel=&quot;shortcut icon&quot; type=&quot;image/png&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;shortcut icon&quot; sizes=&quot;192x192&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
# &lt;link rel=&quot;apple-touch-icon&quot; href=&quot;https://datapane-cdn.com/static/v1/datapane-icon-192x192.png&quot;/&gt;
#
# &lt;script src=&quot;https://kit.fontawesome.com/256c714d9a.js&quot;&gt;&lt;/script&gt;
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.2/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://datapane-cdn.com/v0.16.2/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   // analytics config
#   // TODO -- pass these in as props for consistency?
#   window.dpAppRunner = &quot;False&quot; === &quot;True&quot;;
#   window.dpLocal = true;
#     window.dpLocalViewEvent = true;
#     window.dpReportId = &quot;1d467386194a48349a9ea6ec89cc708d&quot;;
#     window.dpAuthorId = &quot;caa5f20a74684e2fa3c1dc94c4cdf965&quot;;
#
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --dp-accent-color: #4E46E5;
#     --dp-bg-color: #FFF;
#     --dp-text-align: justify;
#     --dp-font-family: Inter var, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#
#   if (!window.dpAppRunner) {
#       // pass app data via props if in local (static) mode, otherwise this data is fetched from the server
#       window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cPlot type=\&quot;application/vnd.vegalite.v4+json\&quot; name=\&quot;plot\&quot; responsive=\&quot;true\&quot; scale=\&quot;1.0\&quot; src=\&quot;ref://e8d3359c6a\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;e8d3359c6a&quot;: {&quot;src&quot;: &quot;data:application/vnd.vegalite.v4+json;base64,...&quot;, &quot;hash&quot;: &quot;e8d3359c6a&quot;, &quot;size&quot;: 21956, &quot;mime&quot;: &quot;application/vnd.vegalite.v4+json&quot;}}} }};
#   }
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://datapane-cdn.com/v0.16.2/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://datapane-cdn.com/v0.16.2/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://datapane-cdn.com/v0.16.2/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#dp-1d467386194a48349a9ea6ec89cc708d");
# </script>

# %%
import altair as alt
import datapane as dp
from vega_datasets import data

df = data.iris()

fig = (
    alt.Chart(df)
    .mark_point()
    .encode(x="petalLength", y="petalWidth", color="species")
)

view = dp.Blocks("# My report", dp.Plot(fig), dp.DataTable(df))
# Out:
# App saved to ./my_report.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3868/3896416478.py in <module>
#      14
#      15 # save as a static HTML-based report
# ---> 16 dp.save_report(view, path="my_report.html").show(open=True)
#
# AttributeError: 'NoneType' object has no attribute 'show'
